# %%
# %matplotlib inline
# %matplotlib notebook

import numpy as np, math
import matplotlib.pyplot as plt

# Create sample dataset
xvalues = np.linspace(20,100, 100)
yvalues = np.array([((np.cos((x-50)/100)*100 + np.sin(x/100)*100 + np.random.normal(0, 13, 1)[0])/150.0) for x in xvalues])
ymin = np.amin(yvalues)
yvalues = [y - ymin for y in yvalues]

# Plot dataset
fig0, ax0 = plt.subplots()
ax0.plot(xvalues,
        yvalues, "ro", linewidth = 2, color = 'red', label = 'target')
ax0.set_xlim(20, 100)
ax0.set_ylim(0, 1)
# Out:
# <img src="data:image/png;base64,...">
# (0, 1)

# %%
# %matplotlib inline
# %matplotlib notebook

#----------
# build the dataset
#----------
from pybrain.datasets import SupervisedDataSet
import numpy as np, math
from nn_utils import train_nn

ds = SupervisedDataSet(1, 1)
for x, y in zip(xvalues, yvalues):
    ds.addSample((x,), (y,))

#----------
# build the network
#----------
net = train_nn(xvalues, yvalues, rate=0.0001, layers = [100,100,100], batch=False, magnification=0.0, iterations = 50)
# Out:
# <img src="data:image/png;base64,...">

# %%
from streamsx.topology.topology import Topology
from my_module import array_yielder, neural_net_model
from streamsx.topology import context
from jupyter_utilities import get_next_line, graph_from_outstream
import time, sys
import matplotlib.pyplot as plt
import random

# Define test data
xdata_raw = [random.uniform(0,100) for x in range(100)]

# Define operators
ay = array_yielder(xdata_raw)
nnm = neural_net_model(net)

# Build Graph
top = Topology("myTop")
stream_ = top.source(ay)
stream_.transform(nnm).print()
# Submit
out = context.submit("STANDALONE", top.graph)

#graph_from_outstream(out, xdata_raw, 20, 100, 0, 1)
# Out:
# May 24, 2016 3:42:18 PM com.ibm.streamsx.topology.internal.streams.InvokeMakeToolkit invoke
# INFO: Invoking spl-make-toolkit
# May 24, 2016 3:42:18 PM com.ibm.streamsx.topology.internal.streams.InvokeMakeToolkit invoke
# INFO: /opt/ibm/InfoSphere_Streams/4.1.1.0/bin/spl-make-toolkit -i /home/streamsadmin/scratch/tk3779226712171603185
# May 24, 2016 3:42:19 PM com.ibm.streamsx.topology.internal.streams.InvokeMakeToolkit invoke
# INFO: spl-make-toolkit complete: return code=0
# May 24, 2016 3:42:19 PM com.ibm.streamsx.topology.internal.streams.InvokeSc getToolkitPath
# INFO: ToolkitPath:/home/streamsadmin/git/streamsx.topology/com.ibm.streamsx.topology:/opt/ibm/InfoSphere_Streams/4.1.1.0/toolkits:/opt/ibm/InfoSphere_Streams/4.1.1.0/toolkits
# May 24, 2016 3:42:19 PM com.ibm.streamsx.topology.internal.streams.InvokeSc invoke
# INFO: Invoking SPL compiler (sc) for main composite: myTop::myTop
# May 24, 2016 3:42:19 PM com.ibm.streamsx.topology.internal.streams.InvokeSc invoke
# INFO: /opt/ibm/InfoSphere_Streams/4.1.1.0/bin/sc --rebuild-toolkits --optimized-code-generation --num-make-threads=4 --standalone -M myTop::myTop -t /home/streamsadmin/git/streamsx.topology/com.ibm.streamsx.topology:/opt/ibm/InfoSphere_Streams/4.1.1.0/toolkits:/opt/ibm/InfoSphere_Streams/4.1.1.0/toolkits
# May 24, 2016 3:42:19 PM com.ibm.streamsx.topology.internal.process.ProcessOutputToLogger run
# SEVERE: CDISP0120W WARNING: The following path is already in the SPL path list: /opt/ibm/InfoSphere_Streams/4.1.1.0/toolkits
# May 24, 2016 3:42:21 PM com.ibm.streamsx.topology.internal.process.ProcessOutputToLogger run
# INFO: Creating the types.
# May 24, 2016 3:42:21 PM com.ibm.streamsx.topology.internal.process.ProcessOutputToLogger run
# INFO: Creating the functions.
# May 24, 2016 3:42:21 PM com.ibm.streamsx.topology.internal.process.ProcessOutputToLogger run
# INFO: Creating the operators.
# May 24, 2016 3:42:21 PM com.ibm.streamsx.topology.internal.process.ProcessOutputToLogger run
# INFO: Creating the processing elements.
# May 24, 2016 3:42:22 PM com.ibm.streamsx.topology.internal.process.ProcessOutputToLogger run
# INFO: The standalone application is being created.
# May 24, 2016 3:42:22 PM com.ibm.streamsx.topology.internal.process.ProcessOutputToLogger run
# INFO: Creating the application model.
# May 24, 2016 3:42:24 PM com.ibm.streamsx.topology.internal.process.ProcessOutputToLogger run
# INFO: Building the binaries.
# May 24, 2016 3:42:24 PM com.ibm.streamsx.topology.internal.process.ProcessOutputToLogger run
# INFO:  [CXX-type] tuple<blob __spl_po>
# May 24, 2016 3:42:24 PM com.ibm.streamsx.topology.internal.process.ProcessOutputToLogger run
# INFO:  [CXX-operator] array_yielder_0
# May 24, 2016 3:42:24 PM com.ibm.streamsx.topology.internal.process.ProcessOutputToLogger run
# INFO:  [CXX-operator] neural_net_model_1
# May 24, 2016 3:42:24 PM com.ibm.streamsx.topology.internal.process.ProcessOutputToLogger run
# INFO:  [CXX-operator] print_flush_2
# May 24, 2016 3:42:25 PM com.ibm.streamsx.topology.internal.process.ProcessOutputToLogger run
# INFO:  [CXX-pe] pe myTop.myTop-a
# May 24, 2016 3:42:25 PM com.ibm.streamsx.topology.internal.process.ProcessOutputToLogger run
# INFO:  [CXX-standalone] standalone
# May 24, 2016 3:42:25 PM com.ibm.streamsx.topology.internal.process.ProcessOutputToLogger run
# INFO:  [LD-standalone] standalone
# May 24, 2016 3:42:26 PM com.ibm.streamsx.topology.internal.process.ProcessOutputToLogger run
# INFO:  [LN-standalone] standalone
# May 24, 2016 3:42:26 PM com.ibm.streamsx.topology.internal.process.ProcessOutputToLogger run
# INFO:  [LD-pe] pe myTop.myTop-a
# May 24, 2016 3:42:26 PM com.ibm.streamsx.topology.internal.process.ProcessOutputToLogger run
# INFO:  [Bundle] myTop.myTop.sab
# May 24, 2016 3:42:49 PM com.ibm.streamsx.topology.internal.streams.InvokeSc invoke
# INFO: SPL compiler complete: return code=0
# May 24, 2016 3:42:50 PM com.ibm.streamsx.topology.internal.context.BundleStreamsContext doSPLCompile
# INFO: Streams Application Bundle produced: myTop.myTop.sab
# May 24, 2016 3:42:50 PM com.ibm.streamsx.topology.internal.streams.InvokeStandalone invoke
# INFO: Invoking standalone application
# May 24, 2016 3:42:50 PM com.ibm.streamsx.topology.internal.streams.InvokeStandalone invoke
# INFO: /opt/ibm/InfoSphere_Streams/4.1.1.0/java/jre/bin/java -jar /home/streamsadmin/scratch/myTop.myTop.sab
# 66.87335072041405
# 91.38728638555223
# 50.394572264082285
# 3.905413652849954
# 73.43426241301479
# 48.67574161674146
# 24.0528852204428
# 8.828950466633112
# 12.471008146127216
# 29.98353665400414
# 42.83766835299583
# 71.05720713709167
# 86.68994823874951
# 93.16353027782498
# 99.5580844568537
# 84.30634450690356
# 97.26699798283742
# 43.98539186037054
# 23.330490631766587
# 41.004272897860815
# 19.72014144402028
# 52.61700740282718
# 61.782316364458886
# 52.8394974515756
# 15.84237142485444
# 77.74805440939623
# 14.784764210577151
# 53.26726916906955
# 45.644773706089715
# 49.7020520249444
# 37.86419579176757
# 72.98921094475702
# 73.8366864263868
# 85.18942214471262
# 69.35905524615522
# 45.47662101660042
# 28.159511765567068
# 12.846096006176966
# 71.64620053073459
# 19.261218471270315
# 90.13669510375475
# 70.47103361720389
# 55.35120557867703
# 87.59847660752276
# 21.93753788972176
# 98.19412028307784
# 58.288726241697454
# 58.470566869209286
# 35.12323767662105
# 52.64051910541353
# 78.60734427117396
# 93.43535457449266
# 74.3665003175526
# 51.448227881906575
# 33.228238276399615
# 77.4952514712803
# 77.38956173872994
# 34.55239500034688
# 14.31196771029083
# 72.40004279294386
# 85.25766363722207
# 79.10668980029565
# 98.70632179611411
# 91.69444210096972
# 46.71931565052506
# 73.64629746696504
# 9.925981399046346
# 61.38876390490462
# 53.009721395543544
# 26.0183827020125
# 49.51978881885202
# 42.97090354809547
# 45.67112830366889
# 82.40550854750475
# 37.61947290292594
# 5.897945029801677
# 10.946377827451236
# 75.17008409966486
# 23.811482672761286
# 82.89352547142691
# 79.97919857100219
# 14.956755192638715
# 34.932922349154246
# 19.79681440112364
# 30.7349111981684
# 93.59468634773017
# 8.08932895143738
# 58.76468794060104
# 9.927903217928469
# 9.95187139159337
# 94.83926613095223
# 16.712301207151693
# 13.87763116574815
# 57.343681282013506
# 33.09020532158271
# 84.34110990304285
# 46.549311442371696
# 70.20409461063022
# 94.54663845124955
# 88.58375044960471
# May 24, 2016 3:43:18 PM com.ibm.streamsx.topology.internal.streams.InvokeStandalone$ProcessFuture get
# INFO: Standalone application completed: return code=0

# %%
top.graph.printJSON()
# Out:
# {
#     "config": {
#         "includes": [
#             {
#                 "source": "/home/streamsadmin/scratch/my_module.py",
#                 "target": "opt/python/modules"
#             },
#             {
#                 "source": "/usr/lib/python3.5/site-packages/pybrain",
#                 "target": "opt/python/packages"
#             },
#             {
#                 "source": "/usr/lib/python3.5/site-packages/numpy",
#                 "target": "opt/python/packages"
#             },
#             {
#                 "source": "/usr/lib/python3.5/site-packages/scipy",
#                 "target": "opt/python/packages"
#             },
#             {
#                 "source": "/usr/lib/python3.5/site-packages/PIL",
#                 "target": "opt/python/packages"
#             },
#             {
#                 "source": "/home/streamsadmin/git/streamsx.topology/com.ibm.streamsx.topology/opt/python/packages/streamsx",
#                 "target": "opt/python/packages"
#             }
#         ]
#     },
#     "name": "myTop",
#     "namespace": "myTop",
#     "operators": [
#         {
#             "config": {},
#             "inputs": [],
#             "kind": "com.ibm.streamsx.topology.functional.python::PyFunctionSource",
#             "name": "array_yielder_0",
#             "outputs": [
#                 {
#                     "connections": [
#                         "neural_net_model_1_IN0"
#                     ],
#                     "name": "array_yielder_0_OUT0",
#                     "type": "tuple<blob __spl_po>"
#                 }
#             ],
#             "parameters": {
#                 "pyCallable": {
#                     "value": "..."
#                 },
#                 "pyModule": {
#                     "value": "my_module"
#                 },
#                 "pyName": {
#                     "value": "array_yielder"
#                 },
#                 "toolkitDir": {
#                     "type": "splexpr",
#                     "value": "getThisToolkitDir()"
#                 }
#             },
#             "partitioned": false
#         },
#         {
#             "config": {},
#             "inputs": [
#                 {
#                     "connections": [
#                         "array_yielder_0_OUT0"
#                     ],
#                     "name": "neural_net_model_1_IN0",
#                     "type": "tuple<blob __spl_po>"
#                 }
#             ],
#             "kind": "com.ibm.streamsx.topology.functional.python::PyFunctionTransform",
#             "name": "neural_net_model_1",
#             "outputs": [
#                 {
#                     "connections": [
#                         "print_flush_2_IN0"
#                     ],
#                     "name": "neural_net_model_1_OUT0",
#                     "type": "tuple<blob __spl_po>"
#                 }
#             ],
#             "parameters": {
#                 "pyCallable": {
#                     "value": "..."
#                 },
#                 "pyModule": {
#                     "value": "my_module"
#                 },
#                 "pyName": {
#                     "value": "neural_net_model"
#                 },
#                 "toolkitDir": {
#                     "type": "splexpr",
#                     "value": "getThisToolkitDir()"
#                 }
#             },
#             "partitioned": false
#         },
#         {
#             "config": {},
#             "inputs": [
#                 {
#                     "connections": [
#                         "neural_net_model_1_OUT0"
#                     ],
#                     "name": "print_flush_2_IN0",
#                     "type": "tuple<blob __spl_po>"
#                 }
#             ],
#             "kind": "com.ibm.streamsx.topology.functional.python::PyFunctionSink",
#             "name": "print_flush_2",
#             "outputs": [],
#             "parameters": {
#                 "pyModule": {
#                     "value": "streamsx.topology.functions"
#                 },
#                 "pyName": {
#                     "value": "print_flush"
#                 },
#                 "toolkitDir": {
#                     "type": "splexpr",
#                     "value": "getThisToolkitDir()"
#                 }
#             },
#             "partitioned": false
#         }
#     ],
#     "public": true
# }

# %%
while True:
    print(g())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-2bdc743f92b0> in <module>()
#       1 while True:
# ----> 2     print(g())
#
# TypeError: 'generator' object is not callable
